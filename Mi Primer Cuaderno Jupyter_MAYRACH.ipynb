# %%
X=rnorm(30)

# %%
X
# Out:
#  [1]  0.97622101 -0.26107429  1.43216104  0.08310388 -0.38899733 -0.39732893
#  [7] -0.27747800 -0.75941243  0.90148676 -0.90629412 -0.41024314  1.73332014
# [13] -0.03340578  1.56457551 -0.16149348  0.44040329  0.18297262 -2.29592909
# [19]  0.90754856 -0.21691284 -1.93307074  0.37277583 -0.19715977 -0.34953797
# [25] -0.10478202 -0.84812488 -0.42934669  0.36696403 -0.77390539 -0.39763837

# %%
hist(X)
# Out:
# Plot with title "Histogram of X"

# %%
hist(X,col="blue")
# Out:
# Plot with title "Histogram of X"
